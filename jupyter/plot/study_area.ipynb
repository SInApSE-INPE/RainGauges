# %%
import os
import pandas as pd
import numpy as np

import geopandas as gpd

import cartopy.feature as cf
import cartopy.crs as ccrs

from matplotlib import patches
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

# %%
# South America
lon_min, lat_min, lon_max, lat_max = -85,-45,-32,13

# %%
SP = gpd.read_file(os.path.join('..','..','geometry','SaoPaulo.geojson'))

# %%
# extract bounds of Sao Paulo geojson
SP_lon_min, SP_lat_min, SP_lon_max, SP_lat_max = SP.total_bounds

# %%
proj = ccrs.PlateCarree()
fig = plt.figure(figsize=(2,2),dpi=300)
gs = gridspec.GridSpec(1,1)

#==================================================================================================
ax1 = plt.subplot(gs[0, 0], projection = proj)
ax1.set_extent([-75,-34,-36,7],crs=proj)
ax1.add_feature(cf.COASTLINE,linewidth=0.1, linestyle='-',edgecolor='k')
ax1.add_feature(cf.BORDERS, linewidth=0.1, linestyle='-', edgecolor='k')

ax1.add_geometries(SP.geometry, ccrs.PlateCarree(), edgecolor='k', facecolor='None', linewidth=0.4, alpha=0.5)

gl = ax1.gridlines(crs=proj,draw_labels=True,linewidth=0.2,color='gray',alpha=0.5,linestyle='--')
gl.top_labels = False
gl.bottom_labels = True
gl.left_labels = True
gl.right_labels = False
gl.xlabel_style = {'size': 6, 'color': 'k'}
gl.ylabel_style = {'size': 6, 'color': 'k'}

ax1.add_patch(patches.Rectangle((lon_max,lat_max),lon_min-lon_max,lat_min-lat_max,linestyle='--',linewidth=0.9,edgecolor='r',facecolor='None',zorder=5))
# ax1.add_patch(patches.Rectangle((SP_lon_max,SP_lat_max),SP_lon_min-SP_lon_max,SP_lat_min-SP_lat_max,linestyle='--',linewidth=0.9,edgecolor='b',facecolor='None',zorder=5))

ax1.set_title('(a) Limits: 75W to 36W and 34S to 7N', fontsize=5, loc='left')

#==================================================================================================
plt.subplots_adjust(left=0.05, right=0.95, top=0.95, bottom=0.05, wspace=0.05, hspace=0.1)

# %%
proj = ccrs.PlateCarree()
fig = plt.figure(figsize=(4,3),dpi=300)
gs = gridspec.GridSpec(1,2)

#==================================================================================================
ax1 = plt.subplot(gs[0, 0], projection = proj)
ax1.set_extent([-87,-30,-60,15],crs=proj)
ax1.add_feature(cf.COASTLINE,linewidth=0.1, linestyle='-',edgecolor='k')
ax1.add_feature(cf.BORDERS, linewidth=0.1, linestyle='-', edgecolor='k')

ax1.add_geometries(SP.geometry, ccrs.PlateCarree(), edgecolor='k', facecolor='None', linewidth=0.4, alpha=0.5)

gl = ax1.gridlines(crs=proj,draw_labels=True,linewidth=0.2,color='gray',alpha=0.5,linestyle='--')
gl.top_labels = False
gl.bottom_labels = True
gl.left_labels = True
gl.right_labels = False
gl.xlabel_style = {'size': 6, 'color': 'k'}
gl.ylabel_style = {'size': 6, 'color': 'k'}

ax1.add_patch(patches.Rectangle((lon_max,lat_max),lon_min-lon_max,lat_min-lat_max,linestyle='--',linewidth=0.9,edgecolor='r',facecolor='None',zorder=5))
# ax1.add_patch(patches.Rectangle((SP_lon_max,SP_lat_max),SP_lon_min-SP_lon_max,SP_lat_min-SP_lat_max,linestyle='--',linewidth=0.9,edgecolor='b',facecolor='None',zorder=5))

ax1.set_title('(a) Limits: 85W to W45 and 32S to 13N', fontsize=5, loc='left')

#==================================================================================================
ax1 = plt.subplot(gs[0, 1], projection = proj)
ax1.set_extent([-87,-30,-60,15],crs=proj)
ax1.add_feature(cf.COASTLINE,linewidth=0.1, linestyle='-',edgecolor='k')
ax1.add_feature(cf.BORDERS, linewidth=0.1, linestyle='-', edgecolor='k')

ax1.add_geometries(SP.geometry, ccrs.PlateCarree(), edgecolor='k', facecolor='None', linewidth=0.4, alpha=0.5)

gl = ax1.gridlines(crs=proj,draw_labels=True,linewidth=0.2,color='gray',alpha=0.5,linestyle='--')
gl.top_labels = False
gl.bottom_labels = True
gl.left_labels = False
gl.right_labels = False
gl.xlabel_style = {'size': 6, 'color': 'k'}
gl.ylabel_style = {'size': 6, 'color': 'k'}

ax1.add_patch(patches.Rectangle((lon_max,lat_max),lon_min-lon_max,(lat_min)-lat_max,linestyle='--',linewidth=0.9,edgecolor='r',facecolor='None',zorder=5))
# ax1.add_patch(patches.Rectangle((SP_lon_max,SP_lat_max),SP_lon_min-SP_lon_max,SP_lat_min-SP_lat_max,linestyle='--',linewidth=0.9,edgecolor='b',facecolor='None',zorder=5))

ax1.set_title('(b) Limits: 85W to W45 and 57S to 13N', fontsize=5, loc='left')

#==================================================================================================
plt.subplots_adjust(left=0.05, right=0.95, top=0.95, bottom=0.05, wspace=0.05, hspace=0.1)
